# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#Read the data in and remove any missing values
#Remove any row with a missing value in any of the columns.
filename='/content/train.csv'
nan_values=['?']
att_type={'target':'category'}

df=pd.read_csv(filename,dtype=att_type,na_values=nan_values)

print(df[df.isna().any(axis=1)])

print(df.shape)
print(df.isnull().sum())
print()
df.dropna(inplace=True)

#print(df.describe())
#df.head()
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []
# (1025, 14)
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(df.dtypes)
df.head()
# Out:
# age            int64
# sex            int64
# cp             int64
# trestbps       int64
# chol           int64
# fbs            int64
# restecg        int64
# thalach        int64
# exang          int64
# oldpeak      float64
# slope          int64
# ca             int64
# thal           int64
# target      category
# dtype: object
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal target
# 0   2     3      0
# 1   0     3      0
# 2   0     3      0
# 3   1     3      0
# 4   3     2      0

# %%
# Splitting the dataset
attr = df.drop(columns = ['target'])  # features
target = df['target']  # target variable
# attr.head()
# target.head()
attr_train, attr_test, target_train,target_test  = train_test_split(attr, target,test_size = 0.25, random_state = 44, shuffle = True)
target_train.head()
# attr_train.head()
target_test.head()
# Out:
# 569    1
# 424    0
# 927    1
# 125    1
# 801    1
# Name: target, dtype: category
# Categories (2, object): ['0', '1']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
k_values = [3, 4,5,6, 10]

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(attr_train, target_train)
    target_pred = knn.predict(attr_test)
#     accuracy = round(np.mean(target_test==target_pred ) * 100, 2)
    accuracy = accuracy_score(target_test,target_pred )
    print(f'Accuracy of model with k = {k}: {accuracy}%')
    print('')
# Out:
# Accuracy of model with k = 3: 0.8404669260700389%
#
# Accuracy of model with k = 4: 0.8093385214007782%
#
# Accuracy of model with k = 5: 0.7665369649805448%
#
# Accuracy of model with k = 6: 0.7665369649805448%
#
# Accuracy of model with k = 10: 0.7509727626459144%

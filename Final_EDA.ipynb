# %%
#Ayushi Gupta
#I pledge my honor that I have abided by the Stevens Honor System.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('HeartDiseasePrediction.csv')
print(df.describe())
df.head()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df['target']=df['target'].astype('category')

# %%
#1: prints summary
summary = df.describe()
print(summary)

print('\n Min, Max, and Mean only')
Min_Max_Mean=df.describe(include=[float, int]).loc[["min", "max", "mean"]]
print(Min_Max_Mean)
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
profile = ProfileReport(df, title="Profiling data frame")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-04-23 01:28:07.634940&quot;&gt;&lt;title&gt;Profiling data frame&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Check for missing values in the dataset
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
pd.crosstab(df['age'], df['target'])
# Out:
# target   0   1
# age
# 29       0   4
# 34       0   6
# 35       7   8
# 37       0   6
# 38       4   8
# 39       4  10
# 40       8   3
# 41       3  29
# 42       4  22
# 43      11  15
# 44      10  26
# 45       6  19
# 46      11  12
# 47       8  10
# 48      11  12
# 49       8   9
# 50       9  12
# 51      10  29
# 52      15  28
# 53       8  18
# 54      21  32
# 55      20  10
# 56      22  17
# 57      36  21
# 58      44  24
# 59      31  15
# 60      27  10
# 61      28   3
# 62      24  13
# 63      23   9
# 64      15  19
# 65      15  12
# 66      11  14
# 67      22   9
# 68       6   6
# 69       3   6
# 70      11   3
# 71       0  11
# 74       0   3
# 76       0   3
# 77       3   0

# %%
pd.plotting.scatter_matrix(df.loc[:, 'age':'thal'], figsize=(36,36), diagonal='hist')
plt.show()

# %%
# Create a box plot
subset=df.loc[:,['age','trestbps', 'chol', 'thalach']]
subset.plot(kind="box", vert=True, figsize=(10, 6))
plt.title("Box plot F7 to F9", fontsize=12)
plt.xlabel("Value")
plt.show()

# %%
subset = df.loc[:, 'age':'thal']

# Create a histogram
subset.hist(grid=False, bins=10, edgecolor="black", linewidth=1.2, xlabelsize=8, ylabelsize=8, figsize=(8, 6))
plt.suptitle("Histogram", fontsize=12)
plt.tight_layout(rect=(0,0,1,0.95))
plt.show()
